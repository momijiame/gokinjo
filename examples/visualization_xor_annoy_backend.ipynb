# %%
# ! pip install "gokinjo[annoy]" scikit-learn matplotlib

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

from gokinjo import knn_kfold_extract

# %% [markdown]
# ### Prepare

# %%
x0 = np.random.rand(500) - 0.5
x1 = np.random.rand(500) - 0.5
X = np.array(list(zip(x0, x1)))
y = np.array([1 if i0 * i1 > 0 else 0 for i0, i1 in X])

# %% [markdown]
# ### Plot original data

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel('x0')
plt.ylabel('x1')
# Out:
# Text(0, 0.5, 'x1')

# %% [markdown]
# ### Extract feature by using Annoy backend

# %%
extracted_features = knn_kfold_extract(X, y, backend='annoy')

# %% [markdown]
# ### Plot extracted data

# %%
plt.scatter(extracted_features[:, 0], extracted_features[:, 1], c=y)
plt.xlabel('k=1, label=0')
plt.ylabel('k=1, label=1')
# Out:
# Text(0, 0.5, 'k=1, label=1')
